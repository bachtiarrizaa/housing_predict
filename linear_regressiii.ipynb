# %%
import pandas as pd

house = pd.read_csv('Housing.csv')

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
house.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
#data = house.drop(columns=['stories', 'prefarea'])

# %%
#data.head()
# Out:
#       price  area  bedrooms  bathrooms mainroad guestroom basement  \
# 0  13300000  7420         4          2      yes        no       no
# 1  12250000  8960         4          4      yes        no       no
# 2  12250000  9960         3          2      yes        no      yes
# 3  12215000  7500         4          2      yes        no      yes
# 4  11410000  7420         4          1      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
data = pd.get_dummies(house, dtype=int)

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_no  \
# 0    13300000  7420         4          2        3        2            0
# 1    12250000  8960         4          4        4        3            0
# 2    12250000  9960         3          2        2        2            0
# 3    12215000  7500         4          2        2        3            0
# 4    11410000  7420         4          1        2        2            0
# ..        ...   ...       ...        ...      ...      ...          ...
# 540   1820000  3000         2          1        1        2            0
# 541   1767150  2400         3          1        1        0            1
# 542   1750000  3620         2          1        1        0            0
# 543   1750000  2910         3          1        1        0            1
# 544   1750000  3850         3          1        2        0            0
#
#      mainroad_yes  guestroom_no  guestroom_yes  ...  basement_yes  \
# ...

# %%
# Mendefinisikan predictions dengan nama fitur dalam bentuk string
predictions = [
    'area',
    'bedrooms',
    'bathrooms',
    'stories',
    'parking',
    'mainroad_no',
    'mainroad_yes',
    'guestroom_no',
    'guestroom_yes',
    'basement_no',
    'basement_yes',
    'hotwaterheating_no',
    'hotwaterheating_yes',
    'airconditioning_no',
    'airconditioning_yes',
    'prefarea_no',
    'prefarea_yes',
    'furnishingstatus_furnished',
    'furnishingstatus_semi-furnished',
    'furnishingstatus_unfurnished'
]

X = data[predictions]
y = data['price']

# %%
# Lakukan normalisasi terhadap fitur X
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# Lakukan normalisasi terhadap label y
scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# Ubah hasil normalisasi menjadi DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
y_scaled = pd.Series(y_scaled.flatten(), name='price')

# Melihat hasil normalisasi
print(X_scaled.head())
# Out:
#        area  bedrooms  bathrooms   stories   parking  mainroad_no  \
# 0  1.046726  1.403419   1.421812  1.378217  1.517692    -0.405623
# 1  1.757010  1.403419   5.405809  2.532024  2.679409    -0.405623
# 2  2.218232  0.047278   1.421812  0.224410  1.517692    -0.405623
# 3  1.083624  1.403419   1.421812  0.224410  2.679409    -0.405623
# 4  1.046726  1.403419  -0.570187  0.224410  1.517692    -0.405623
#
#    mainroad_yes  guestroom_no  guestroom_yes  basement_no  basement_yes  \
# 0      0.405623      0.465315      -0.465315     0.734539     -0.734539
# 1      0.405623      0.465315      -0.465315     0.734539     -0.734539
# 2      0.405623      0.465315      -0.465315    -1.361397      1.361397
# 3      0.405623      0.465315      -0.465315    -1.361397      1.361397
# 4      0.405623     -2.149083       2.149083    -1.361397      1.361397
#
#    hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 0            0.219265            -0.219265           -1.472618
# ...

# %%
X_scaled.head()
# Out:
#        area  bedrooms  bathrooms   stories   parking  mainroad_no  \
# 0  1.046726  1.403419   1.421812  1.378217  1.517692    -0.405623
# 1  1.757010  1.403419   5.405809  2.532024  2.679409    -0.405623
# 2  2.218232  0.047278   1.421812  0.224410  1.517692    -0.405623
# 3  1.083624  1.403419   1.421812  0.224410  2.679409    -0.405623
# 4  1.046726  1.403419  -0.570187  0.224410  1.517692    -0.405623
#
#    mainroad_yes  guestroom_no  guestroom_yes  basement_no  basement_yes  \
# 0      0.405623      0.465315      -0.465315     0.734539     -0.734539
# 1      0.405623      0.465315      -0.465315     0.734539     -0.734539
# 2      0.405623      0.465315      -0.465315    -1.361397      1.361397
# 3      0.405623      0.465315      -0.465315    -1.361397      1.361397
# 4      0.405623     -2.149083       2.149083    -1.361397      1.361397
#
#    hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 0            0.219265            -0.219265           -1.472618
# ...

# %%
y_scaled.head()
# Out:
# 0    4.566365
# 1    4.004484
# 2    4.004484
# 3    3.985755
# 4    3.554979
# Name: price, dtype: float64

# %%
print(y_scaled.head())
# Out:
# 0    4.566365
# 1    4.004484
# 2    4.004484
# 3    3.985755
# 4    3.554979
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Misalkan X_scaled dan y_scaled sudah ada
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.1, random_state=123)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.6800786064314188

# %%
r_squared = model.score(X_test, y_test)
print(f'R² Score: {r_squared:.3f}')
# Out:
# R² Score: 0.680

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Misalkan model dan scaler telah dilatih sebelumnya
# model = ...
# scaler_X = ...
# scaler_y = ...

def predict_house_price(area, bedrooms, bathrooms, parking, stories, mainroad_no, mainroad_yes, 
                        guestroom_no, guestroom_yes, basement_no, basement_yes, 
                        hotwaterheating_no, hotwaterheating_yes, 
                        airconditioning_no, airconditioning_yes,
                        prefarea_no, prefarea_yes,
                        furnishingstatus_furnished, furnishingstatus_semi_furnished, 
                        furnishingstatus_unfurnished):
    
    # Mengemas input fitur ke dalam DataFrame
    input_data = pd.DataFrame({
        'area': [area],
        'bedrooms': [bedrooms],
        'bathrooms': [bathrooms],
        'stories': [stories],
        'parking': [parking],
        'mainroad_no': [mainroad_no],
        'mainroad_yes': [mainroad_yes],
        'guestroom_no': [guestroom_no],
        'guestroom_yes': [guestroom_yes],
        'basement_no': [basement_no],
        'basement_yes': [basement_yes],
        'hotwaterheating_no': [hotwaterheating_no],
        'hotwaterheating_yes': [hotwaterheating_yes],
        'airconditioning_no': [airconditioning_no],
        'airconditioning_yes': [airconditioning_yes],
        'prefarea_no': [prefarea_no],
        'prefarea_yes': [prefarea_yes],
        'furnishingstatus_furnished': [furnishingstatus_furnished],
        'furnishingstatus_semi-furnished': [furnishingstatus_semi_furnished],
        'furnishingstatus_unfurnished': [furnishingstatus_unfurnished]
    })

    # Normalisasi input data
    input_data_scaled = scaler_X.transform(input_data)
    
    # Melakukan prediksi
    predicted_price_scaled = model.predict(input_data_scaled)
    
    # Kembalikan harga ke skala asli
    predicted_price = scaler_y.inverse_transform(predicted_price_scaled.reshape(-1, 1))
    
    return predicted_price[0][0]

# Contoh penggunaan fungsi
predicted_price = predict_house_price(
    area=3850,
    bedrooms=3,
    bathrooms=1,
    stories=2,
    parking=0,
    mainroad_no=0,
    mainroad_yes=1,
    guestroom_no=1,
    guestroom_yes=0,
    basement_no=1,
    basement_yes=0,
    hotwaterheating_no=1,
    hotwaterheating_yes=0,
    airconditioning_no=1,
    airconditioning_yes=0,
    prefarea_no=1,
    prefarea_yes=0,
    furnishingstatus_furnished=0,
    furnishingstatus_semi_furnished=0,
    furnishingstatus_unfurnished=1
)

print(f'Predicted House Price: {predicted_price:.2f}')
# Out:
# Predicted House Price: 3287383.48
# E:\bachtiar\notebook\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
